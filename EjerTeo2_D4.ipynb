# %%
import numpy as np
def equation(x):
    return (np.sin(np.pi*x))

# %%
import matplotlib.pyplot as plt
# Generate x values
x = np.linspace(-10, 10, 200)

# Calculate y values
y = equation(x)
# Plot the equation
plt.plot(x, y, label = '$f(x)$', color = 'BLUE')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $f(x)$')
ax = plt.gca()
ax.set_ylim([-1.5,1.5])
ax.set_xlim([-5, 5])
plt.grid(True)
# Marca los ejes coordenados
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.savefig('GraficoET2.jpg')
plt.show()

# %%
from typing import Callable
def sign(x: float) -> int:
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

# %%
def bisection(
    a: float, b: float, *, equation: Callable[[float], float], tol: float, N: int
) -> tuple[float, float, float, int] | None:
    i = 1
    assert a < b, "a not lower than b, the interval is not valid."

    assert (equation(a) * equation(b) < 0), "The function does not change sign over the interval."

    Fa = equation(a)
    p = a # to avoid crash in i == 0.
    for i in range(1,N+1):
        p = a + (b - a) / 2
        FP = equation(p)
        if FP == 0 or (b - a) / 2 < tol:
            return p, a, b, i

        if sign(Fa) * sign(FP) > 0:
            a = p
            Fa = FP
        else:
            b = p
    print("Solución no encontrada, número de iteraciones insuficiente para la tolerancia dada.")

# %% [markdown]
# #### a)

# %%
a = -0.8
b = 2.5
tol = 10**(-5)
result = bisection(a=a,b=b,equation=equation,tol=tol,N=20)
print("Luego de "+str(result[3])+ " iteraciones la solución aproximada dentro de la presición de "+format(tol,".0E")+" es: "+format(result[0],".5"))
# Out:
# Luego de 19 iteraciones la solución aproximada dentro de la presición de 1E-05 es: 5.5313e-06

# %% [markdown]
# #### b)

# %%
a = -0.8
b = 3
tol = 10**(-5)
result = bisection(a=a,b=b,equation=equation,tol=tol,N=20)
print("Luego de "+str(result[3])+ " iteraciones la solución aproximada dentro de la presición de "+format(tol,".0E")+" es: "+format(result[0],".5"))
# Out:
# Luego de 19 iteraciones la solución aproximada dentro de la presición de 1E-05 es: 2.0

# %% [markdown]
# #### c)

# %%
a = -0.8
b = 2.8
tol = 10**(-5)
result = bisection(a=a,b=b,equation=equation,tol=tol,N=20)
print("Luego de "+str(result[3])+ " iteraciones la solución aproximada dentro de la presición de "+format(tol,".0E")+" es: "+format(result[0],".5"))
# Out:
# Luego de 19 iteraciones la solución aproximada dentro de la presición de 1E-05 es: 3.8147e-06
